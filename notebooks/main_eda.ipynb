# %%
import pandas as pd

movies = pd.read_csv('../data.csv')
movies.info()
movies.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB
#                                              name rating      genre  year  \
# ...

# %%
print(movies.isna().sum())
print(len(movies))
print(len(movies.dropna()))
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64
# 7668
# 5421

# %%
print(movies.runtime.value_counts())
print(len(movies.runtime.value_counts()))
print(sum(movies.runtime.isna()))
print(max(movies.runtime))
print(min(movies.runtime))
# print(movies[movies["director"] == "Directors"])
# Out:
# runtime
# 97.0     240
# 90.0     226
# 98.0     222
# 100.0    220
# 96.0     215
#         ...
# 242.0      1
# 210.0      1
# 224.0      1
# 196.0      1
# 209.0      1
# Name: count, Length: 138, dtype: int64
# 138
# 4
# 366.0
# 55.0

# %%
import seaborn as sns
sns.pairplot(movies)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
